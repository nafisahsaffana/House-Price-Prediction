# %% [markdown]
# ### Data loading

# %%
import numpy as np
import pandas as pd

# %%
# Load data
pd.set_option('display.max_columns', None)
data = pd.read_csv("E:\College\cl\data (cl)\house_price\jabodetabek_house_price.csv")
data.head(1)
# Out:
#                                                  url   price_in_rp
# 0  https://www.rumah123.com/properti/bekasi/hos11...  2.990000e+09  \
#
#                                                title
# 0  Rumah cantik Sumarecon Bekasi\r\nLingkungan as...  \
#
#                      address           district     city       lat
# 0  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945  \
#
#          long                                    facilities property_type
# 0  106.986275  Tempat Jemuran, Jalur Telepon, Taman,  Taman         rumah  \
#
#         ads_id  bedrooms  bathrooms  land_size_m2  building_size_m2  carports
# 0  hos11360272       4.0        4.0         239.0             272.0       0.0  \
#
#                   certificate electricity  maid_bedrooms  maid_bathrooms
# 0  shm - sertifikat hak milik    4400 mah            0.0             1.0  \
#
#    floors  building_age  year_built property_condition building_orientation
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3553 entries, 0 to 3552
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   url                   3553 non-null   object
#  1   price_in_rp           3553 non-null   float64
#  2   title                 3553 non-null   object
#  3   address               3553 non-null   object
#  4   district              3553 non-null   object
#  5   city                  3553 non-null   object
#  6   lat                   3553 non-null   float64
#  7   long                  3553 non-null   float64
#  8   facilities            3553 non-null   object
#  9   property_type         3552 non-null   object
#  10  ads_id                3549 non-null   object
#  11  bedrooms              3519 non-null   float64
#  12  bathrooms             3524 non-null   float64
#  13  land_size_m2          3551 non-null   float64
# ...

# %%
data.describe()
# Out:
#         price_in_rp          lat         long     bedrooms    bathrooms
# count  3.553000e+03  3553.000000  3553.000000  3519.000000  3524.000000  \
# mean   4.191685e+09    -6.324721   106.792881     3.326513     2.624858
# std    1.375067e+10     0.129245     0.172159     2.672148     2.696497
# min    4.200000e+07    -6.894828   106.402315     1.000000     1.000000
# 25%    8.000000e+08    -6.397933   106.687295     2.000000     2.000000
# 50%    1.500000e+09    -6.300733   106.799954     3.000000     2.000000
# 75%    3.590000e+09    -6.231754   106.874766     4.000000     3.000000
# max    5.800000e+11    -6.102478   109.771691    99.000000    99.000000
#
#        land_size_m2  building_size_m2     carports  maid_bedrooms
# count   3551.000000       3551.000000  3553.000000    3553.000000  \
# mean     204.806815        186.587440     1.197861       0.496482
# std      402.127746        248.443471     1.114996       0.685723
# ...

# %%
data.hist(bins=50,figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'price_in_rp'}>,
#         <Axes: title={'center': 'lat'}>,
#         <Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'bedrooms'}>],
#        [<Axes: title={'center': 'bathrooms'}>,
#         <Axes: title={'center': 'land_size_m2'}>,
#         <Axes: title={'center': 'building_size_m2'}>,
#         <Axes: title={'center': 'carports'}>],
#        [<Axes: title={'center': 'maid_bedrooms'}>,
#         <Axes: title={'center': 'maid_bathrooms'}>,
#         <Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'building_age'}>],
#        [<Axes: title={'center': 'year_built'}>,
#         <Axes: title={'center': 'garages'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# Above histograms shows that most of the features are skewed

# %%
data.hist(bins=50,figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'price_in_rp'}>,
#         <Axes: title={'center': 'lat'}>,
#         <Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'bedrooms'}>],
#        [<Axes: title={'center': 'bathrooms'}>,
#         <Axes: title={'center': 'land_size_m2'}>,
#         <Axes: title={'center': 'building_size_m2'}>,
#         <Axes: title={'center': 'carports'}>],
#        [<Axes: title={'center': 'maid_bedrooms'}>,
#         <Axes: title={'center': 'maid_bathrooms'}>,
#         <Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'building_age'}>],
#        [<Axes: title={'center': 'year_built'}>,
#         <Axes: title={'center': 'garages'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
data['price_in_rp']
# Out:
# 0       2.990000e+09
# 1       1.270000e+09
# 2       1.950000e+09
# 3       3.300000e+09
# 4       4.500000e+09
#             ...
# 3548    5.880000e+08
# 3549    7.850000e+08
# 3550    7.550000e+08
# 3551    8.000000e+08
# 3552    6.550000e+08
# Name: price_in_rp, Length: 3553, dtype: float64

# %% [markdown]
# ### Data Transformation

# %% [markdown]
# ### Data Preparation

# %%
missing_values = data.isnull().sum()

# Display columns with missing values
print(missing_values[missing_values > 0])
# Out:
# property_type              1
# ads_id                     4
# bedrooms                  34
# bathrooms                 29
# land_size_m2               2
# building_size_m2           2
# certificate              141
# floors                     6
# building_age            1445
# year_built              1445
# property_condition       246
# building_orientation    1647
# furnishing               387
# dtype: int64

# %%
data.property_condition.value_counts()

# %%
# data.facilities.value_counts()

# %%
data.certificate.value_counts()
# Out:
# certificate
# shm - sertifikat hak milik       3001
# hgb - hak guna bangunan           209
# lainnya (ppjb,girik,adat,dll)     201
# hp - hak pakai                      1
# Name: count, dtype: int64

# %%
data.bedrooms.value_counts()

# %%
data.bathrooms.value_counts()

# %%
data.maid_bedrooms.value_counts()

# %%
data.floors.value_counts()

# %%
data.year_built.value_counts()

# %%
data.furnishing.value_counts()

# %%
# data.garages.value_counts()

# %%
data.address.value_counts()
# Out:
# address
# Sentul City, Bogor                   282
# Alam Sutera, Tangerang               115
# Gading Serpong, Tangerang             97
# Pantai Indah Kapuk, Jakarta Utara     94
# BSD, Tangerang                        83
#                                     ...
# Fatmawati, Jakarta Selatan             1
# Ragunan, Jakarta Selatan               1
# Radio Dalam, Jakarta Selatan           1
# Raffles Hills, Jakarta Timur           1
# Sudimara, Tangerang                    1
# Name: count, Length: 397, dtype: int64

# %%
data.district.value_counts()
# Out:
# district
# Sentul City           282
# Alam Sutera           115
# Gading Serpong         97
# Pantai Indah Kapuk     94
# BSD                    83
#                      ...
# Kedungbadak             1
# Daan Mogot              1
# Kedoya Utara            1
# Menteng Atas            1
# Sudimara                1
# Name: count, Length: 380, dtype: int64

# %%
data.property_type.value_counts()
# Out:
# property_type
# rumah    3552
# Name: count, dtype: int64

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# - ganti property type jadi "kost" untuk tittle yang ada kata "kos", "kost", "kontrakan" dan kamarnya lebih dari 15
# - hapus data yang property typenya "kost"
#
# drop : title, ads_id, year_built, building_age, building_orientation, garages, property_condition, building_orientation
# *property condition dihapus karena value seperti unfurnished, semi furnished, furnished, baru sudah ada di kolom "furnishing" dan value lainnya tidak memiliki parameter yang jelas

# %%
# Menghilangkan data yang tidak termasuk kedalam rentang longitude dan latitude jabodetabek
data = data.loc[(data['lat'] >= -6.6) & (data['lat'] <= -6.1) & (data['long'] >= 106.6) & (data['long'] <= 107.1)]
data
# Out:
#                                                     url   price_in_rp
# 0     https://www.rumah123.com/properti/bekasi/hos11...  2.990000e+09  \
# 1     https://www.rumah123.com/properti/bekasi/hos10...  1.270000e+09
# 2     https://www.rumah123.com/properti/bekasi/hos10...  1.950000e+09
# 3     https://www.rumah123.com/properti/bekasi/hos10...  3.300000e+09
# 4     https://www.rumah123.com/properti/bekasi/hos10...  4.500000e+09
# ...                                                 ...           ...
# 3548  https://www.rumah123.com/properti/tangerang/ho...  5.880000e+08
# 3549  https://www.rumah123.com/properti/tangerang/ho...  7.850000e+08
# 3550  https://www.rumah123.com/properti/tangerang/ho...  7.550000e+08
# 3551  https://www.rumah123.com/properti/tangerang/ho...  8.000000e+08
# 3552  https://www.rumah123.com/properti/tangerang/ho...  6.550000e+08
#
#                                                   title
# 0     Rumah cantik Sumarecon Bekasi\r\nLingkungan as...  \
# ...

# %%
# Mengubah 'property_type' menjadi 'kost' untuk baris dengan 'title' yang mengandung 'kos', 'kost', atau 'kontrakan' dan 'bedrooms' lebih dari 15
data.loc[(data['title'].str.contains('kos|kost|kontrakan', case=False)) & (data['bedrooms'] > 15), 'property_type'] = 'kost'
data.loc[(data['title'].str.contains('ruko', case=False)), 'property_type'] = 'ruko'

# %%
data.property_type.value_counts()
# Out:
# property_type
# rumah    2973
# kost        7
# ruko        2
# Name: count, dtype: int64

# %%
# Mengganti nilai bedrooms dengan penjumlahan bedrooms dan maid bedrooms
data['bedrooms'].fillna(0, inplace=True)
data['maid_bedrooms'].fillna(0, inplace=True)

data['bedrooms'] = data['bedrooms'] + data['maid_bedrooms']

# %%
data['bedrooms'].isnull().sum()
# Out:
# 0

# %%
# Mengganti nilai bedrooms dengan penjumlahan bedrooms dan maid bedrooms
data['bathrooms'].fillna(0, inplace=True)
data['maid_bathrooms'].fillna(0, inplace=True)

data['bathrooms'] = data['bathrooms'] + data['maid_bathrooms']

# %%
data['bathrooms'].isnull().sum()
# Out:
# 0

# %%
# Menghapus baris di mana 'land_size_m2' adalah NaN
data = data.dropna(subset=['land_size_m2'])

# %%
data['land_size_m2'].isnull().sum()
# Out:
# 0

# %%
# Menghapus baris di mana 'land_size_m2' adalah NaN
data = data.dropna(subset=['building_size_m2'])

# %%
data['building_size_m2'].isnull().sum()
# Out:
# 0

# %%
data['certificate'].fillna(0, inplace=True)

# %%
data['furnishing'].fillna(0, inplace=True)

# %%
# Mengganti nilai 'facilities' dengan jumlah fasilitas
data['facilities'] = data['facilities'].apply(lambda x: len(x.split(',')))

# %%
# Menghilangkan kata 'mah' dalam kolom 'electricity'
data['electricity'] = data['electricity'].str.replace('mah', '')

# %%
# Hapus baris dengan nilai 'property_type' selain 'rumah'
data = data[data['property_type'] == 'rumah']

# %%
data.drop(columns=['url','title','address', 'ads_id', 'year_built', 'building_age','property_type', 'building_orientation', 'garages', 'property_condition','maid_bedrooms','maid_bathrooms'], inplace=True)

# %%
data.head()
# Out:
#     price_in_rp           district     city       lat        long  facilities
# 0  2.990000e+09  Summarecon Bekasi   Bekasi -6.223945  106.986275           4  \
# 1  1.270000e+09  Summarecon Bekasi   Bekasi -6.223945  106.986275           1
# 2  1.950000e+09  Summarecon Bekasi   Bekasi -6.223945  106.986275           6
# 3  3.300000e+09  Summarecon Bekasi   Bekasi -6.223945  106.986275          10
# 4  4.500000e+09  Summarecon Bekasi   Bekasi -6.223945  106.986275           5
#
#    bedrooms  bathrooms  land_size_m2  building_size_m2  carports
# 0       4.0        5.0         239.0             272.0       0.0  \
# 1       3.0        2.0          55.0              69.0       1.0
# 2       4.0        4.0         119.0             131.0       1.0
# 3       4.0        4.0         180.0             174.0       0.0
# 4       5.0        4.0         328.0             196.0       2.0
#
#                   certificate electricity  floors   furnishing
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder()

# %%
# Mengubah data dalam kolom menjadi string
data['certificate'] = data['certificate'].astype(str)
data['furnishing'] = data['furnishing'].astype(str)

# %%
#Mengubah data menjadi angka
data['district']= label_encoder.fit_transform(data['district']) 
data['city']= label_encoder.fit_transform(data['city']) 
data['certificate']= label_encoder.fit_transform(data['certificate']) 
data['furnishing']= label_encoder.fit_transform(data['furnishing']) 

data.tail()
# Out:
#       price_in_rp  district  city       lat        long  facilities  bedrooms
# 3548  588000000.0       162     8 -6.296615  106.704601          10       2.0  \
# 3549  785000000.0       202     8 -6.283454  106.638775          11       3.0
# 3550  755000000.0       202     8 -6.283454  106.638775           7       3.0
# 3551  800000000.0        17     8 -6.288237  106.665859           6       3.0
# 3552  655000000.0       292     8 -6.296963  106.710635          15       3.0
#
#       bathrooms  land_size_m2  building_size_m2  carports  certificate
# 3548        1.0          72.0              36.0       1.0            4  \
# 3549        2.0          85.0              60.0       1.0            4
# 3550        2.0          78.0              60.0       1.0            4
# 3551        2.0          60.0              65.0       2.0            4
# 3552        2.0          64.0              60.0       1.0            4
#
#      electricity  floors  furnishing
# ...

# %%
import matplotlib.pyplot as plt
import folium

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2972 entries, 0 to 3552
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price_in_rp       2972 non-null   float64
#  1   district          2972 non-null   int32
#  2   city              2972 non-null   int32
#  3   lat               2972 non-null   float64
#  4   long              2972 non-null   float64
#  5   facilities        2972 non-null   int64
#  6   bedrooms          2972 non-null   float64
#  7   bathrooms         2972 non-null   float64
#  8   land_size_m2      2972 non-null   float64
#  9   building_size_m2  2972 non-null   float64
#  10  carports          2972 non-null   float64
#  11  certificate       2972 non-null   int32
#  12  electricity       2972 non-null   object
#  13  floors            2969 non-null   float64
#  14  furnishing        2972 non-null   int32
# dtypes: float64(9), int32(4), int64(1), object(1)
# ...

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=data['long'],y=data['lat'],alpha=0.1)
plt.title("Distribution of households",size=16)
# Out:
# Text(0.5, 1.0, 'Distribution of households')

# %%
import matplotlib

# %%
# #memeriksa oulier
# import matplotlib.pyplot as plt

# plt.boxplot(data['price_in_rp'])
# plt.show()


from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(data['price_in_rp']))
outliers = data['price_in_rp'][z_scores > 3]

# %%
map = folium.Map(location=[-6.2, 106.8], zoom_start=10)
norm = matplotlib.colors.Normalize(vmin=data['price_in_rp'].min(), vmax=data['price_in_rp'].max())
cmap = matplotlib.cm.get_cmap("jet")
for index, row in data.iterrows():
    color = matplotlib.colors.rgb2hex(cmap(norm(row['price_in_rp'])))
    folium.CircleMarker(location=(row["lat"], row["long"]),
                        radius=5,
                        color=color,
                        fill=True,
                        fill_opacity=0.5).add_to(map)
map
# Out:
# C:\Users\saffana\AppData\Local\Temp\ipykernel_16332\3369428433.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = matplotlib.cm.get_cmap("jet")
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.head(1)
# Out:
#     price_in_rp  district  city       lat        long  facilities  bedrooms
# 0  2.990000e+09       297     0 -6.223945  106.986275           4       4.0  \
#
#    bathrooms  land_size_m2  building_size_m2  carports  certificate
# 0        5.0         239.0             272.0       0.0            4  \
#
#   electricity  floors  furnishing
# 0       4400      2.0           4

# %%
plt.figure(figsize=(12,12))
img=plt.imread('jabodetabek.jpg')
plt.imshow(img, zorder=0, extent=[106.5, 107.1, -6.4, -6.1])
# x=data['long']
# y=data['long']
# s=data['land_size_m2']
# c=data['price_in_rp']

plt.scatter(x=data['long'],y=data['lat'],alpha=0.5,c=data['price_in_rp']/30,s=data['land_size_m2'],
            cmap=plt.get_cmap("jet"),zorder=1,label='price_in_rp')
plt.colorbar()
plt.title("Distribution of households",size=16)
plt.legend()

# %%
#mencari data yang menunjukan letak di cirebon
import reverse_geocoder as rg
import pandas as pd

# Membuat DataFrame baru
new_data = pd.DataFrame(columns=['lat', 'long', 'address'])

for index, row in data.iterrows():
    coordinates = (row['lat'], row['long'])
    result = rg.search(coordinates)  # Melakukan geocoding balik
    address = result[0]['name'] + ', ' + result[0]['admin1'] + ', ' + result[0]['admin2'] + ', ' + result[0]['cc']
    new_data = new_data.append({'lat': row['lat'], 'long': row['long'], 'address': address}, ignore_index=True)
# Out:
# Loading formatted geocoded file...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16332\954583016.py in ?()
#       8 for index, row in data.iterrows():
#       9     coordinates = (row['lat'], row['long'])
#      10     result = rg.search(coordinates)  # Melakukan geocoding balik
#      11     address = result[0]['name'] + ', ' + result[0]['admin1'] + ', ' + result[0]['admin2'] + ', ' + result[0]['cc']
# ---> 12     new_data = new_data.append({'lat': row['lat'], 'long': row['long'], 'address': address}, ignore_index=True)
#      13
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
# ...

# %% [markdown]
# https://github.com/sonarsushant/California-House-Price-Prediction/blob/master/EDA%20and%20Data%20Cleaning.ipynb

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# ### Modeling

# %% [markdown]
# ### Evaluation
